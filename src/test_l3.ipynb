# %% [markdown]
# ### 多変量データの可視化? with_ pyplot

# %%
import numpy as np
import pandas as pd
import scipy as sp

## 実行に無関係なエラーメッセージを消す
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pyplot as plt
# %matplotlib inline

## いい感じのグラフを出力する
import seaborn as sns
sns.set()

# %% [markdown]
# ### 折れ線グラフの描画

# %%
x = np.arange(1, 16, 1)
y = np.arange(2, 17, 1)
np.random.shuffle(y)
## 描画
plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("random y")

## グラフの画像を保存
# plt.savefig("test_l3.jpg")
# Out:
# Text(0, 0.5, 'random y')

# %% [markdown]
# ### ヒストグラムの描画

# %%
fish_data = np.array([2, 2, 3, 3, 4, 4, 4, 4, 5, 5, 6, 7])
sns.distplot(fish_data, bins=5)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### 2変量データに対するヒストグラム

# %%
fish_multi = pd.read_csv('data/3-3-2-fish_multi_2.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
fish_multi.groupby("species").describe()
# Out:
#         length
#          count mean       std  min   25%  50%   75%  max
# species
# A         10.0  4.0  1.154701  2.0  3.25  4.0  4.75  6.0
# B         10.0  7.0  1.154701  5.0  6.25  7.0  7.75  9.0

# %%
length_a = fish_multi.query('species == "A"')["length"]
length_b = fish_multi.query('species == "B"')["length"]

# %%
sns.distplot(length_a, kde=False, bins = 5)
sns.distplot(length_b, kde=False, bins = 5)
# Out:
# <AxesSubplot:xlabel='length'>

# %% [markdown]
# ### 箱ひげ図の描画

# %%
sns.boxplot(x="species", y="length", data=fish_multi)
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %% [markdown]
# ### 散布図の描画

# %%
cov_data = pd.read_csv('./data/3-2-3-cov.csv')
cov_data.head()
# Out:
#       x   y
# 0  18.5  34
# 1  18.7  39
# 2  19.1  41
# 3  19.7  38
# 4  21.5  45

# %%
sns.jointplot(x="x", y="y", data=cov_data)

# %% [markdown]
# ### ペアプロット

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.groupby("species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
sns.pairplot(iris, hue="species")
